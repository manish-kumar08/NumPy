# %% [markdown]
# #  Headings
# ## Explore Jupyter Notebook
# ## NumPy
#
# This is a regular text
#
# ---
#
# - Task List 1
# - Task List 2
#
# --- Shortcuts
#
# --- ctrl + Enter  -> Run the current cell and stay on the same cell
#
# --- shift + Enter -> Run the current cell and move to the next cell
#
# --- alt + Enter   -> Run the current cell and create a new cell below
#
# --- Esc + up/down ( j / k )-> Select the previous/next cell
#
# --- a -> above , b -> below , m -> markdown , y -> code
#
# --- d-d -> delete cell

# %%
print('Hello')
print('Hello World !')
# Out:
# Hello
# Hello World !

# %%
print('Manish')
# Out:
# Manish
